# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp
from tensorflow.keras import layers
from sklearn import preprocessing

import datetime
import math

# %%
def process_data():
    df_test = pd.read_csv(r'../test_data_clean', sep = ",", engine='python')
    df_train = pd.read_csv(r'../train_data_clean', sep = ",", engine='python')

    test = df_test.drop(df_test.columns[0],axis=1)

    test_targets = test.iloc[:,[13]]
    test_inputs = test.loc[:,test.columns != 'target']

    train = df_train.drop(df_train.columns[0],axis=1)
    train_targets = train.iloc[:,[13]]
    train_inputs = train.loc[:,train.columns != 'target']
    
    np.savez('Spotify_data_train', inputs=train_inputs, targets=train_targets)
    np.savez('Spotify_data_test', inputs=test_inputs, targets=test_targets)

    npz = np.load('Spotify_data_train.npz')
    train_inputs,train_targets = npz['inputs'].astype(np.float),npz['targets'].astype(np.int)

    npz = np.load('Spotify_data_test.npz')
    test_inputs, test_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

    test_inputs = preprocessing.scale(test_inputs)
    
    return train_inputs,train_targets,test_inputs,test_targets

train_inputs,train_targets,test_inputs,test_targets = process_data()
total_samples = len(train_inputs)
split = math.ceil(total_samples/5)
k = 5

# %%
def crossFold(train_inputs,train_targets,i):
    
    if(i==0):
        validation_inputs = preprocessing.scale(train_inputs[:split])
        validation_targets = train_targets[:split]
        inputs = preprocessing.scale(train_inputs[split:])
        targets = train_targets[split:]
    elif(i == 4):
        validation_inputs = preprocessing.scale(train_inputs[i*split:])
        validation_targets = train_targets[i*split:]
        inputs = preprocessing.scale(train_inputs[:i*split])
        targets = train_targets[:i*split]
    else:
        i1 = train_inputs[:i*split]
        i2 = train_inputs[(i+1)*split:]
        inputs = preprocessing.scale(np.concatenate((i1,i2)))
        
        it1 = train_targets[:i*split]
        it2 = train_targets[(i+1)*split:]
        targets = np.concatenate((it1,it2))
        
        validation_inputs = preprocessing.scale(train_inputs[i*split:(i+1)*split])
        validation_targets = train_targets[i*split:(i+1)*split]
        
    return inputs,targets,validation_inputs,validation_targets

# %%
#Setting the parameter values we are trying to test

number_of_layers = [10,17,30]
number_of_node = []
optimizers = ['adam','RMSprop','sgd']
batch_sizes = []
max_epochs = []
regulizer_param = []

HP_NUM_LAYERS = hp.HParam('num_layers', hp.Discrete([2,5]))
HP_NUM_NODES = hp.HParam('num_nodes', hp.Discrete([10,17,30])) 
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(optimizers))
HP_BATCH_SIZE = hp.HParam('batch_size', hp.Discrete([10,50])) 
HP_MAX_EPOCHS = hp.HParam('max_epochs', hp.Discrete([5,10,25]))
HP_L2 = hp.HParam('l2 regularizer', hp.RealInterval(0.001,0.01))

METRIC_ACCURACY = 'accuracy'

with tf.summary.create_file_writer('logs/hparam_tuning1').as_default():
    hp.hparams_config(
    hparams=[HP_NUM_LAYERS,HP_NUM_NODES,HP_OPTIMIZER,HP_BATCH_SIZE, HP_MAX_EPOCHS,HP_L2], 
    metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
  )
   
        
def train_test_model(run_dir,hparams,t_inputs,t_targets,v_inputs,v_targets): 
    
    
    input_size = 17 
    output_size = 1
    
    
    model = tf.keras.Sequential()
    model.add(layers.Dense(hparams[HP_NUM_NODES], activation='relu',input_shape=(input_size,)))
    for i in range(hparams[HP_NUM_LAYERS]-1):
        model.add(layers.Dense(hparams[HP_NUM_NODES],kernel_regularizer=tf.keras.regularizers.l2(hparams[HP_L2]), activation='relu'))
    model.add(layers.Dense(output_size, activation='sigmoid'))
    
    model.compile(optimizer=hparams[HP_OPTIMIZER], loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy'])
    
   
    batch_size = hparams[HP_BATCH_SIZE]
    max_epochs = hparams[HP_MAX_EPOCHS]
    
    callbacksList = [
        tf.keras.callbacks.TensorBoard(run_dir,histogram_freq=1,update_freq=1,embeddings_freq=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=0.001, patience=8, mode='max',baseline=None),
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=8, verbose=0, mode='min',baseline=0.6)
    ]
        
    history = model.fit(  t_inputs,t_targets,
                          batch_size=batch_size,
                          epochs=max_epochs, 
                          validation_data=(v_inputs, v_targets),
                          callbacks=callbacksList,
                          verbose = 0) 

    test_loss,test_accuracy = model.evaluate(test_inputs, test_targets)
    
    
    return test_loss, test_accuracy   
    
def run(run_dir,hparams,t_inputs,t_targets,v_inputs,v_targets):
    with tf.summary.create_file_writer(run_dir+"/Kfold"+str(i)).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_test_model(run_dir+"/Kfold"+str(i),hparams,t_inputs,t_targets,v_inputs,v_targets)
       
        tf.summary.scalar("loss",accuracy[0],step=session_num)
        tf.summary.scalar(METRIC_ACCURACY, accuracy[1], step=session_num)

    return accuracy[1]

# %%
session_num = 0
start = datetime.datetime.now()


for num_layers in HP_NUM_LAYERS.domain.values:
    for num_nodes in HP_NUM_NODES.domain.values:
        for optimizer in HP_OPTIMIZER.domain.values:
            for batch_size in HP_BATCH_SIZE.domain.values:
                for max_epoch in HP_MAX_EPOCHS.domain.values:
                        for l2 in (HP_L2.domain.min_value, HP_L2.domain.max_value):
                            hparams = {
                                HP_NUM_LAYERS: num_layers,
                                HP_NUM_NODES: num_nodes,
                                HP_OPTIMIZER: optimizer,
                                HP_BATCH_SIZE: batch_size, 
                                HP_MAX_EPOCHS: max_epoch,
                                HP_L2: l2,
                            }
                            combined_acc = 0
                            
                            start_time_run = datetime.datetime.now()
                            
                            for i in range(5):
                                start_time_fold = datetime.datetime.now()
                                t_inputs,t_targets,v_inputs,v_targets = crossFold(train_inputs,train_targets,i)
                                run_name = "run-%d" % session_num
                                print('----------- Starting trial: %s' % run_name + '-----------')
                                print({h.name: hparams[h] for h in hparams})
                                print("Fold nr "+str(i+1))
                                
                                accuracy = run('logs/hparam_tuning1/' + run_name, hparams,t_inputs,t_targets,v_inputs,v_targets)
                                combined_acc += accuracy
                                
                        
                                finished_time = datetime.datetime.now()
                                
                                print('Total time elapsed: ', finished_time-start,'\n')
                                print('Time elapsed for fold: ', finished_time-start_time_fold ,'\n')
                            
                            combined_acc = combined_acc/k
                            tf.summary.scalar('Combined accuray:', combined_acc , step=1)
                            print("Combined accuray: ",combined_acc,'\n')
                            
                            print('Time elapsed for run: ',finished_time-start_time_run)
                            
                            
                            session_num += 1

print("----- Session finished -----")
# Out:
# ----------- Starting trial: run-0-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:From c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0016s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0716s). Check your callbacks.
#  1/71 [..............................] - ETA: 0s - loss: 0.5245 - accuracy: 0.6875WARNING:tensorflow:Callbacks method `on_test_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_begin` time: 0.0010s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5987 - accuracy: 0.6636
# Total time elapsed:  0:00:13.692025
#
# Time elapsed for fold:  0:00:13.690994
#
# ----------- Starting trial: run-0-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.2401s). Check your callbacks.
# 71/71 [==============================] - 0s 981us/step - loss: 0.5937 - accuracy: 0.6759
# Total time elapsed:  0:00:26.936246
#
# Time elapsed for fold:  0:00:13.241227
#
# ----------- Starting trial: run-0-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0023s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.1611s). Check your callbacks.
# 71/71 [==============================] - 0s 999us/step - loss: 0.5903 - accuracy: 0.6794
# Total time elapsed:  0:00:40.437085
#
# Time elapsed for fold:  0:00:13.496851
#
# ----------- Starting trial: run-0-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0030s vs `on_train_batch_end` time: 0.1583s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5882 - accuracy: 0.6838
# Total time elapsed:  0:00:54.173142
#
# Time elapsed for fold:  0:00:13.734075
#
# ----------- Starting trial: run-0-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0019s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.1622s). Check your callbacks.
# 71/71 [==============================] - 0s 923us/step - loss: 0.5857 - accuracy: 0.6821
# Total time elapsed:  0:01:07.389877
#
# Time elapsed for fold:  0:00:13.211747
#
# Combined accuray:  0.6769705057144165
#
# Time elapsed for run:  0:01:07.388846
# ----------- Starting trial: run-1-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0006s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0006s vs `on_train_batch_end` time: 0.1661s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.6065 - accuracy: 0.6605
# Total time elapsed:  0:01:20.701920
#
# Time elapsed for fold:  0:00:13.308079
#
# ----------- Starting trial: run-1-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.2640s). Check your callbacks.
# 71/71 [==============================] - 0s 885us/step - loss: 0.6038 - accuracy: 0.6706
# Total time elapsed:  0:01:34.738109
#
# Time elapsed for fold:  0:00:14.032197
#
# ----------- Starting trial: run-1-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1525s). Check your callbacks.
# 71/71 [==============================] - 0s 997us/step - loss: 0.6096 - accuracy: 0.6495
# Total time elapsed:  0:01:48.151952
#
# Time elapsed for fold:  0:00:13.411850
#
# ----------- Starting trial: run-1-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1600s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.6020 - accuracy: 0.6737
# Total time elapsed:  0:02:01.492021
#
# Time elapsed for fold:  0:00:13.335083
#
# ----------- Starting trial: run-1-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1486s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5990 - accuracy: 0.6689
# Total time elapsed:  0:02:14.857681
#
# Time elapsed for fold:  0:00:13.362667
#
# Combined accuray:  0.6646411299705506
#
# Time elapsed for run:  0:01:07.463840
# ----------- Starting trial: run-2-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3110s). Check your callbacks.
# 71/71 [==============================] - 0s 899us/step - loss: 0.5862 - accuracy: 0.6843
# Total time elapsed:  0:02:40.928028
#
# Time elapsed for fold:  0:00:26.065351
#
# ----------- Starting trial: run-2-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3518s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5974 - accuracy: 0.6755
# Total time elapsed:  0:03:07.001827
#
# Time elapsed for fold:  0:00:26.070822
#
# ----------- Starting trial: run-2-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3305s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5860 - accuracy: 0.6900
# Total time elapsed:  0:03:29.982389
#
# Time elapsed for fold:  0:00:22.978575
#
# ----------- Starting trial: run-2-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4670s). Check your callbacks.
# 71/71 [==============================] - 0s 973us/step - loss: 0.5868 - accuracy: 0.6799
# Total time elapsed:  0:03:56.686718
#
# Time elapsed for fold:  0:00:26.699344
#
# ----------- Starting trial: run-2-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3647s). Check your callbacks.
# 71/71 [==============================] - 0s 835us/step - loss: 0.5967 - accuracy: 0.6781
# Total time elapsed:  0:04:17.688268
#
# Time elapsed for fold:  0:00:20.997554
#
# Combined accuray:  0.6815499663352966
#
# Time elapsed for run:  0:02:02.825591
# ----------- Starting trial: run-3-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3732s). Check your callbacks.
# 71/71 [==============================] - 0s 922us/step - loss: 0.5938 - accuracy: 0.6799
# Total time elapsed:  0:04:44.509298
#
# Time elapsed for fold:  0:00:26.820025
#
# ----------- Starting trial: run-3-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0018s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3502s). Check your callbacks.
# 71/71 [==============================] - 0s 959us/step - loss: 0.5831 - accuracy: 0.6869
# Total time elapsed:  0:05:10.905219
#
# Time elapsed for fold:  0:00:26.393940
#
# ----------- Starting trial: run-3-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4058s). Check your callbacks.
# 71/71 [==============================] - 0s 922us/step - loss: 0.5868 - accuracy: 0.6874
# Total time elapsed:  0:05:31.837992
#
# Time elapsed for fold:  0:00:20.931768
#
# ----------- Starting trial: run-3-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3301s). Check your callbacks.
# 71/71 [==============================] - 0s 910us/step - loss: 0.5911 - accuracy: 0.6830
# Total time elapsed:  0:05:57.175712
#
# Time elapsed for fold:  0:00:25.335763
#
# ----------- Starting trial: run-3-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4859s). Check your callbacks.
# 71/71 [==============================] - 0s 907us/step - loss: 0.5823 - accuracy: 0.6772
# Total time elapsed:  0:06:23.157048
#
# Time elapsed for fold:  0:00:25.980341
#
# Combined accuray:  0.6828709721565247
#
# Time elapsed for run:  0:02:05.467775
# ----------- Starting trial: run-4-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3359s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5832 - accuracy: 0.6931
# Total time elapsed:  0:07:18.119925
#
# Time elapsed for fold:  0:00:54.960886
#
# ----------- Starting trial: run-4-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3286s). Check your callbacks.
# 71/71 [==============================] - 0s 815us/step - loss: 0.5772 - accuracy: 0.6909
# Total time elapsed:  0:08:16.363264
#
# Time elapsed for fold:  0:00:58.243339
#
# ----------- Starting trial: run-4-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0016s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4691s). Check your callbacks.
# 71/71 [==============================] - 0s 939us/step - loss: 0.5914 - accuracy: 0.6786
# Total time elapsed:  0:08:37.040740
#
# Time elapsed for fold:  0:00:20.675478
#
# ----------- Starting trial: run-4-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3286s). Check your callbacks.
# 71/71 [==============================] - 0s 915us/step - loss: 0.5862 - accuracy: 0.6803
# Total time elapsed:  0:09:23.632303
#
# Time elapsed for fold:  0:00:46.591563
#
# ----------- Starting trial: run-4-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0012s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3809s). Check your callbacks.
# 71/71 [==============================] - 0s 965us/step - loss: 0.5831 - accuracy: 0.6918
# Total time elapsed:  0:10:21.303544
#
# Time elapsed for fold:  0:00:57.669246
#
# Combined accuray:  0.6869220614433289
#
# Time elapsed for run:  0:03:58.144505
# ----------- Starting trial: run-5-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0018s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3274s). Check your callbacks.
# 71/71 [==============================] - 0s 897us/step - loss: 0.5885 - accuracy: 0.6821
# Total time elapsed:  0:10:56.692673
#
# Time elapsed for fold:  0:00:35.384146
#
# ----------- Starting trial: run-5-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3303s). Check your callbacks.
#  1/71 [..............................] - ETA: 0s - loss: 0.5194 - accuracy: 0.6875WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5788 - accuracy: 0.6909
# Total time elapsed:  0:11:58.043471
#
# Time elapsed for fold:  0:01:01.349800
#
# ----------- Starting trial: run-5-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0006s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0006s vs `on_train_batch_end` time: 0.3293s). Check your callbacks.
# 71/71 [==============================] - 0s 817us/step - loss: 0.5907 - accuracy: 0.6764
# Total time elapsed:  0:12:19.028645
#
# Time elapsed for fold:  0:00:20.984178
#
# ----------- Starting trial: run-5-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0008s vs `on_train_batch_end` time: 0.3275s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5855 - accuracy: 0.6821
# Total time elapsed:  0:13:16.369126
#
# Time elapsed for fold:  0:00:57.337490
#
# ----------- Starting trial: run-5-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3393s). Check your callbacks.
# 71/71 [==============================] - 0s 958us/step - loss: 0.5800 - accuracy: 0.6935
# Total time elapsed:  0:14:15.410935
#
# Time elapsed for fold:  0:00:59.040815
#
# Combined accuray:  0.6849845886230469
#
# Time elapsed for run:  0:03:54.102408
# ----------- Starting trial: run-6-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3246s). Check your callbacks.
# 71/71 [==============================] - 0s 906us/step - loss: 0.6009 - accuracy: 0.6728
# Total time elapsed:  0:14:52.658314
#
# Time elapsed for fold:  0:00:37.246376
#
# ----------- Starting trial: run-6-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3318s). Check your callbacks.
# 71/71 [==============================] - 0s 901us/step - loss: 0.5805 - accuracy: 0.6909
# Total time elapsed:  0:15:32.157611
#
# Time elapsed for fold:  0:00:39.497298
#
# ----------- Starting trial: run-6-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0017s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3282s). Check your callbacks.
# 71/71 [==============================] - 0s 903us/step - loss: 0.5923 - accuracy: 0.6737
# Total time elapsed:  0:15:52.195739
#
# Time elapsed for fold:  0:00:20.038128
#
# ----------- Starting trial: run-6-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4132s). Check your callbacks.
# 71/71 [==============================] - 0s 904us/step - loss: 0.5861 - accuracy: 0.6825
# Total time elapsed:  0:16:49.365193
#
# Time elapsed for fold:  0:00:57.167458
#
# ----------- Starting trial: run-6-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.3417s). Check your callbacks.
# 71/71 [==============================] - 0s 907us/step - loss: 0.5816 - accuracy: 0.6913
# Total time elapsed:  0:18:28.024535
#
# Time elapsed for fold:  0:01:38.659342
#
# Combined accuray:  0.6822545170783997
#
# Time elapsed for run:  0:04:12.612597
# ----------- Starting trial: run-7-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.01}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3307s). Check your callbacks.
# 71/71 [==============================] - 0s 905us/step - loss: 0.5916 - accuracy: 0.6794
# Total time elapsed:  0:18:48.380385
#
# Time elapsed for fold:  0:00:20.354848
#
# ----------- Starting trial: run-7-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.01}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3283s). Check your callbacks.
# 71/71 [==============================] - 0s 912us/step - loss: 0.5813 - accuracy: 0.6808
# Total time elapsed:  0:19:13.364933
#
# Time elapsed for fold:  0:00:24.984548
#
# ----------- Starting trial: run-7-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.01}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4613s). Check your callbacks.
# 71/71 [==============================] - 0s 897us/step - loss: 0.6004 - accuracy: 0.6768
# Total time elapsed:  0:19:33.577122
#
# Time elapsed for fold:  0:00:20.209182
#
# ----------- Starting trial: run-7-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.01}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4050s). Check your callbacks.
# 71/71 [==============================] - 0s 874us/step - loss: 0.5721 - accuracy: 0.6984
# Total time elapsed:  0:21:12.990518
#
# Time elapsed for fold:  0:01:39.412395
#
# ----------- Starting trial: run-7-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.01}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3286s). Check your callbacks.
# 71/71 [==============================] - 0s 957us/step - loss: 0.5738 - accuracy: 0.6997
# Total time elapsed:  0:22:09.221893
#
# Time elapsed for fold:  0:00:56.230374
#
# Combined accuray:  0.687010133266449
#
# Time elapsed for run:  0:03:41.196356
# ----------- Starting trial: run-8-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3408s). Check your callbacks.
# 71/71 [==============================] - 0s 737us/step - loss: 0.6040 - accuracy: 0.6513
# Total time elapsed:  0:22:16.496083
#
# Time elapsed for fold:  0:00:07.273190
#
# ----------- Starting trial: run-8-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.2190s). Check your callbacks.
# 71/71 [==============================] - 0s 960us/step - loss: 0.5972 - accuracy: 0.6684
# Total time elapsed:  0:22:24.133377
#
# Time elapsed for fold:  0:00:07.635300
#
# ----------- Starting trial: run-8-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1575s). Check your callbacks.
# 71/71 [==============================] - 0s 857us/step - loss: 0.6038 - accuracy: 0.6649
# Total time elapsed:  0:22:31.272969
#
# Time elapsed for fold:  0:00:07.139592
#
# ----------- Starting trial: run-8-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0920s). Check your callbacks.
# 71/71 [==============================] - 0s 906us/step - loss: 0.5888 - accuracy: 0.6812
# Total time elapsed:  0:22:38.251573
#
# Time elapsed for fold:  0:00:06.976610
#
# ----------- Starting trial: run-8-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.001}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.1494s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5987 - accuracy: 0.6733
# Total time elapsed:  0:22:45.491894
#
# Time elapsed for fold:  0:00:07.236343
#
# Combined accuray:  0.6678115367889405
#
# Time elapsed for run:  0:00:36.269001
# ----------- Starting trial: run-9-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0007s vs `on_train_batch_begin` time: 0.0014s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0007s vs `on_train_batch_end` time: 0.0909s). Check your callbacks.
# 71/71 [==============================] - 0s 887us/step - loss: 0.5952 - accuracy: 0.6680
# Total time elapsed:  0:22:52.757225
#
# Time elapsed for fold:  0:00:07.260344
#
# ----------- Starting trial: run-9-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1748s). Check your callbacks.
#  1/71 [..............................] - ETA: 0s - loss: 0.5673 - accuracy: 0.6250WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5962 - accuracy: 0.6680
# Total time elapsed:  0:23:00.254299
#
# Time elapsed for fold:  0:00:07.496070
#
# ----------- Starting trial: run-9-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1150s). Check your callbacks.
# 71/71 [==============================] - 0s 887us/step - loss: 0.6012 - accuracy: 0.6693
# Total time elapsed:  0:23:07.315441
#
# Time elapsed for fold:  0:00:07.060141
#
# ----------- Starting trial: run-9-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1481s). Check your callbacks.
# 71/71 [==============================] - 0s 885us/step - loss: 0.5983 - accuracy: 0.6565
# Total time elapsed:  0:23:14.089374
#
# Time elapsed for fold:  0:00:06.772936
#
# ----------- Starting trial: run-9-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 5, 'l2 regularizer': 0.01}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.0881s). Check your callbacks.
# 71/71 [==============================] - 0s 904us/step - loss: 0.5910 - accuracy: 0.6653
# Total time elapsed:  0:23:21.294573
#
# Time elapsed for fold:  0:00:07.201196
#
# Combined accuray:  0.6654337167739868
#
# Time elapsed for run:  0:00:35.797692
# ----------- Starting trial: run-10-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1517s). Check your callbacks.
# 71/71 [==============================] - 0s 888us/step - loss: 0.5904 - accuracy: 0.6733
# Total time elapsed:  0:23:34.978837
#
# Time elapsed for fold:  0:00:13.683230
#
# ----------- Starting trial: run-10-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1731s). Check your callbacks.
# 71/71 [==============================] - 0s 871us/step - loss: 0.5929 - accuracy: 0.6764
# Total time elapsed:  0:23:48.250439
#
# Time elapsed for fold:  0:00:13.268586
#
# ----------- Starting trial: run-10-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1464s). Check your callbacks.
# 71/71 [==============================] - 0s 915us/step - loss: 0.5917 - accuracy: 0.6786
# Total time elapsed:  0:23:59.137198
#
# Time elapsed for fold:  0:00:10.885757
#
# ----------- Starting trial: run-10-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.0854s). Check your callbacks.
# 71/71 [==============================] - 0s 903us/step - loss: 0.5945 - accuracy: 0.6733
# Total time elapsed:  0:24:15.540663
#
# Time elapsed for fold:  0:00:16.402516
#
# ----------- Starting trial: run-10-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.001}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3267s). Check your callbacks.
# 71/71 [==============================] - 0s 866us/step - loss: 0.5908 - accuracy: 0.6733
# Total time elapsed:  0:24:28.871961
#
# Time elapsed for fold:  0:00:13.330366
#
# Combined accuray:  0.6749449849128724
#
# Time elapsed for run:  0:01:07.576354
# ----------- Starting trial: run-11-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1507s). Check your callbacks.
# 71/71 [==============================] - 0s 909us/step - loss: 0.5851 - accuracy: 0.6759
# Total time elapsed:  0:24:42.492962
#
# Time elapsed for fold:  0:00:13.620000
#
# ----------- Starting trial: run-11-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.2395s). Check your callbacks.
# 71/71 [==============================] - 0s 886us/step - loss: 0.5894 - accuracy: 0.6821
# Total time elapsed:  0:24:55.949624
#
# Time elapsed for fold:  0:00:13.456662
#
# ----------- Starting trial: run-11-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0007s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0007s vs `on_train_batch_end` time: 0.1659s). Check your callbacks.
# 71/71 [==============================] - 0s 869us/step - loss: 0.5840 - accuracy: 0.6799
# Total time elapsed:  0:25:06.811787
#
# Time elapsed for fold:  0:00:10.860164
#
# ----------- Starting trial: run-11-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0015s vs `on_train_batch_end` time: 0.0880s). Check your callbacks.
# 71/71 [==============================] - 0s 904us/step - loss: 0.5970 - accuracy: 0.6675
# Total time elapsed:  0:25:17.955915
#
# Time elapsed for fold:  0:00:11.142131
#
# ----------- Starting trial: run-11-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0019s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.4111s). Check your callbacks.
# 71/71 [==============================] - 0s 876us/step - loss: 0.5883 - accuracy: 0.6728
# Total time elapsed:  0:25:31.752765
#
# Time elapsed for fold:  0:00:13.796850
#
# Combined accuray:  0.6756494879722595
#
# Time elapsed for run:  0:01:02.879803
# ----------- Starting trial: run-12-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1473s). Check your callbacks.
# 71/71 [==============================] - 0s 893us/step - loss: 0.5808 - accuracy: 0.6944
# Total time elapsed:  0:25:57.704195
#
# Time elapsed for fold:  0:00:25.949431
#
# ----------- Starting trial: run-12-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3216s). Check your callbacks.
# 71/71 [==============================] - 0s 928us/step - loss: 0.5911 - accuracy: 0.6816
# Total time elapsed:  0:26:28.770906
#
# Time elapsed for fold:  0:00:31.062718
#
# ----------- Starting trial: run-12-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0018s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3284s). Check your callbacks.
# 71/71 [==============================] - 0s 883us/step - loss: 0.5736 - accuracy: 0.6931
# Total time elapsed:  0:27:01.301661
#
# Time elapsed for fold:  0:00:32.529754
#
# ----------- Starting trial: run-12-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3248s). Check your callbacks.
# 71/71 [==============================] - 0s 891us/step - loss: 0.5784 - accuracy: 0.6887
# Total time elapsed:  0:27:33.615214
#
# Time elapsed for fold:  0:00:32.312555
#
# ----------- Starting trial: run-12-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0016s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3315s). Check your callbacks.
# 71/71 [==============================] - 0s 882us/step - loss: 0.5811 - accuracy: 0.6852
# Total time elapsed:  0:28:06.111499
#
# Time elapsed for fold:  0:00:32.495283
#
# Combined accuray:  0.6885953307151794
#
# Time elapsed for run:  0:02:34.356735
# ----------- Starting trial: run-13-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3251s). Check your callbacks.
# 71/71 [==============================] - 0s 730us/step - loss: 0.5779 - accuracy: 0.6913
# Total time elapsed:  0:28:38.294798
#
# Time elapsed for fold:  0:00:32.179305
#
# ----------- Starting trial: run-13-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3230s). Check your callbacks.
# 71/71 [==============================] - 0s 869us/step - loss: 0.5814 - accuracy: 0.6808
# Total time elapsed:  0:29:10.296364
#
# Time elapsed for fold:  0:00:32.001566
#
# ----------- Starting trial: run-13-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3275s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5854 - accuracy: 0.6764
# Total time elapsed:  0:29:21.152956
#
# Time elapsed for fold:  0:00:10.855593
#
# ----------- Starting trial: run-13-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.1096s). Check your callbacks.
# 71/71 [==============================] - 0s 908us/step - loss: 0.5806 - accuracy: 0.6922
# Total time elapsed:  0:29:53.416410
#
# Time elapsed for fold:  0:00:32.258459
#
# ----------- Starting trial: run-13-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3266s). Check your callbacks.
# 71/71 [==============================] - 0s 929us/step - loss: 0.5835 - accuracy: 0.6764
# Total time elapsed:  0:30:25.725539
#
# Time elapsed for fold:  0:00:32.308127
#
# Combined accuray:  0.6833994030952454
#
# Time elapsed for run:  0:02:19.611042
# ----------- Starting trial: run-14-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3440s). Check your callbacks.
# 71/71 [==============================] - 0s 882us/step - loss: 0.5818 - accuracy: 0.6825
# Total time elapsed:  0:31:00.382812
#
# Time elapsed for fold:  0:00:34.653283
#
# ----------- Starting trial: run-14-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3306s). Check your callbacks.
# 71/71 [==============================] - 0s 928us/step - loss: 0.5801 - accuracy: 0.6948
# Total time elapsed:  0:32:07.001291
#
# Time elapsed for fold:  0:01:06.615560
#
# ----------- Starting trial: run-14-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3271s). Check your callbacks.
# 71/71 [==============================] - 0s 931us/step - loss: 0.5814 - accuracy: 0.6825
# Total time elapsed:  0:32:33.272234
#
# Time elapsed for fold:  0:00:26.269061
#
# ----------- Starting trial: run-14-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0016s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3276s). Check your callbacks.
# 71/71 [==============================] - 0s 926us/step - loss: 0.5996 - accuracy: 0.6781
# Total time elapsed:  0:32:44.268991
#
# Time elapsed for fold:  0:00:10.994765
#
# ----------- Starting trial: run-14-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0006s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0006s vs `on_train_batch_end` time: 0.0894s). Check your callbacks.
# 71/71 [==============================] - 0s 963us/step - loss: 0.5761 - accuracy: 0.6860
# Total time elapsed:  0:33:44.220651
#
# Time elapsed for fold:  0:00:59.950662
#
# Combined accuray:  0.6848084568977356
#
# Time elapsed for run:  0:03:18.491122
# ----------- Starting trial: run-15-----------
# {'num_layers': 1, 'num_nodes': 5, 'optimizer': 'RMSprop', 'batch_size': 10, 'max_epochs': 50, 'l2 regularizer': 0.01}
# Fold nr 1
# ...
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3282s). Check your callbacks.
# 71/71 [==============================] - 0s 899us/step - loss: 0.5822 - accuracy: 0.6750
# Total time elapsed:  8:37:19.618542
#
# Time elapsed for fold:  0:00:26.221112
#
# Combined accuray:  0.6853368520736695
#
# Time elapsed for run:  0:02:10.959572
# ----------- Starting trial: run-355-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0021s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3235s). Check your callbacks.
# 71/71 [==============================] - 0s 918us/step - loss: 0.5794 - accuracy: 0.6896
# Total time elapsed:  8:37:49.792335
#
# Time elapsed for fold:  0:00:30.171800
#
# ----------- Starting trial: run-355-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3251s). Check your callbacks.
# 71/71 [==============================] - 0s 923us/step - loss: 0.5808 - accuracy: 0.6821
# Total time elapsed:  8:38:15.833882
#
# Time elapsed for fold:  0:00:26.040762
#
# ----------- Starting trial: run-355-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0016s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3243s). Check your callbacks.
# 71/71 [==============================] - 0s 892us/step - loss: 0.5772 - accuracy: 0.6874
# Total time elapsed:  8:38:37.342426
#
# Time elapsed for fold:  0:00:21.506547
#
# ----------- Starting trial: run-355-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0014s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3187s). Check your callbacks.
# 71/71 [==============================] - 0s 885us/step - loss: 0.5733 - accuracy: 0.6856
# Total time elapsed:  8:39:03.772616
#
# Time elapsed for fold:  0:00:26.428193
#
# ----------- Starting trial: run-355-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 10, 'l2 regularizer': 0.01}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3219s). Check your callbacks.
# 71/71 [==============================] - 0s 896us/step - loss: 0.5761 - accuracy: 0.6891
# Total time elapsed:  8:39:29.723847
#
# Time elapsed for fold:  0:00:25.948233
#
# Combined accuray:  0.6867459177970886
#
# Time elapsed for run:  0:02:10.103312
# ----------- Starting trial: run-356-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0021s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3186s). Check your callbacks.
# 71/71 [==============================] - 0s 884us/step - loss: 0.5758 - accuracy: 0.6957
# Total time elapsed:  8:40:35.273694
#
# Time elapsed for fold:  0:01:05.547851
#
# ----------- Starting trial: run-356-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3479s). Check your callbacks.
# 71/71 [==============================] - 0s 911us/step - loss: 0.5738 - accuracy: 0.6843
# Total time elapsed:  8:41:22.603559
#
# Time elapsed for fold:  0:00:47.327873
#
# ----------- Starting trial: run-356-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0020s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3306s). Check your callbacks.
# 71/71 [==============================] - 0s 950us/step - loss: 0.5682 - accuracy: 0.6900
# Total time elapsed:  8:42:04.479880
#
# Time elapsed for fold:  0:00:41.875317
#
# ----------- Starting trial: run-356-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_begin` time: 0.0016s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3246s). Check your callbacks.
# 71/71 [==============================] - 0s 871us/step - loss: 0.5704 - accuracy: 0.6922
# Total time elapsed:  8:43:06.937101
#
# Time elapsed for fold:  0:01:02.456223
#
# ----------- Starting trial: run-356-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.001}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3275s). Check your callbacks.
# 71/71 [==============================] - 0s 922us/step - loss: 0.5708 - accuracy: 0.6988
# Total time elapsed:  8:44:08.078221
#
# Time elapsed for fold:  0:01:01.140122
#
# Combined accuray:  0.692206084728241
#
# Time elapsed for run:  0:04:38.352378
# ----------- Starting trial: run-357-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3307s). Check your callbacks.
# 71/71 [==============================] - 0s 904us/step - loss: 0.5710 - accuracy: 0.6984
# Total time elapsed:  8:45:11.095096
#
# Time elapsed for fold:  0:01:03.012885
#
# ----------- Starting trial: run-357-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 2
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3274s). Check your callbacks.
# 71/71 [==============================] - 0s 934us/step - loss: 0.5696 - accuracy: 0.6909
# Total time elapsed:  8:46:12.838153
#
# Time elapsed for fold:  0:01:01.741072
#
# ----------- Starting trial: run-357-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 3
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_train_batch_end` time: 0.3531s). Check your callbacks.
# 71/71 [==============================] - 0s 911us/step - loss: 0.5691 - accuracy: 0.7023
# Total time elapsed:  8:47:10.701021
#
# Time elapsed for fold:  0:00:57.858872
#
# ----------- Starting trial: run-357-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 4
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0021s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3223s). Check your callbacks.
# 71/71 [==============================] - 0s 1ms/step - loss: 0.5642 - accuracy: 0.6918
# Total time elapsed:  8:48:17.811068
#
# Time elapsed for fold:  0:01:07.107055
#
# ----------- Starting trial: run-357-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 25, 'l2 regularizer': 0.01}
# Fold nr 5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0011s vs `on_train_batch_end` time: 0.3473s). Check your callbacks.
# 71/71 [==============================] - 0s 716us/step - loss: 0.5698 - accuracy: 0.6997
# Total time elapsed:  8:48:54.921645
#
# Time elapsed for fold:  0:00:37.106587
#
# Combined accuray:  0.6966094136238098
#
# Time elapsed for run:  0:04:46.839434
# ----------- Starting trial: run-358-----------
# {'num_layers': 1, 'num_nodes': 30, 'optimizer': 'sgd', 'batch_size': 5, 'max_epochs': 50, 'l2 regularizer': 0.001}
# Fold nr 1
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_begin` time: 0.0012s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0005s vs `on_train_batch_end` time: 0.3601s). Check your callbacks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8f45091eba0b> in <module>
#      29                                 print("Fold nr "+str(i+1))
#      30
# ---> 31                                 accuracy = run('logs/hparam_tuning/' + run_name, hparams,t_inputs,t_targets,v_inputs,v_targets)
#      32                                 combined_acc += accuracy
#      33
#
# <ipython-input-4-6db65737a444> in run(run_dir, hparams, t_inputs, t_targets, v_inputs, v_targets)
#     106     with tf.summary.create_file_writer(run_dir+"/Kfold"+str(i)).as_default():
#     107         hp.hparams(hparams)  # record the values used in this trial
# --> 108         accuracy = train_test_model(run_dir+"/Kfold"+str(i),hparams,t_inputs,t_targets,v_inputs,v_targets)
#     109         #
#     110         #accuracy= tf.reshape(tf.convert_to_tensor(accuracy), []).numpy()
#
# <ipython-input-4-6db65737a444> in train_test_model(run_dir, hparams, t_inputs, t_targets, v_inputs, v_targets)
#      87                                 #tf.keras.callbacks.TensorBoard.on_epoch_end(epoch,logs=None)
#      88                                 ,
# ---> 89                               verbose = 0)
#      90
#      91     test_loss,test_accuracy = model.evaluate(test_inputs, test_targets)
#
# c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# c:\users\espen grødem\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
