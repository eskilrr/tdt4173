# %%
import spotipy
import time
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
cid = "b3c5b350c6cb43c2bdb403eb3b896eba"
secret = "fa1aa37ba9c943d3b4e2cadc8fd4818f"
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids
ids = getTrackIDs('Billboard', '6UeSakyzhiEt4NB3UAd6NQ')
print(len(ids))
# Out:
# 100

# %%
def getTrackIDsFromAlbum(album_id):
    ids2 = []
    #playlist = sp.user_playlist(user, playlist_id)
    album = sp.album(album_id)
    for item in album['tracks']['items']:
        ids2.append(item['id'])
    return ids2

ids2 = getTrackIDsFromAlbum('2Y9IRtehByVkegoD7TcLfi')
print(len(ids2))
print(ids2)
# Out:
# 18
# ['0aGQHMr7bc23Y9Ts84ffop', '1Se0r96r0gnqg67kJPmESc', '1G391cbiT3v3Cywg8T7DM1', '64BbK9SFKH2jk86U3dGj2P', '0GcWf1Cc4ixN35D3O9VdcP', '48UPSzbZjgc449aqz8bxox', '3QJnjJH53Ocg22MaLutrgJ', '6WUjz18yIeTGDR1E69WHtf', '2xDHUsWEsH33sKbFqDZPFj', '2bo1tTjK87OHKKUDFthqHx', '49colNVoLFcMszng9O8w4h', '0O8RjwNco465s5o9Ix9IYj', '0tGkxA0oybkQ3iR6LLXPjZ', '66wnTJJ7Vo0GW02CMP3etR', '1XxCiPw07rd1ytYnE7SoJI', '3BW34zpQNgRUwuQ4eUyzMN', '0809RpHic1xrZzh9CT4wXo', '28w7CPWQCqQxt0YCzDN75b']

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
tracks = []
for i in range(len(ids)):
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df.head()
# Out:
#                                            name  \
# 0  Savage Love (Laxed – Siren Beat) [BTS Remix]
# 1                                      Dynamite
# 2               WAP (feat. Megan Thee Stallion)
# 3                        Mood (feat. iann dior)
# 4          Laugh Now Cry Later (feat. Lil Durk)
#
#                                           album     artist release_date  \
# 0  Savage Love (Laxed - Siren Beat) [BTS Remix]  Jawsh 685   2020-10-02
# 1                                      Dynamite        BTS   2020-08-21
# 2               WAP (feat. Megan Thee Stallion)    Cardi B   2020-08-07
# 3                        Mood (feat. iann dior)   24kGoldn   2020-07-24
# 4          Laugh Now Cry Later (feat. Lil Durk)      Drake   2020-08-14
#
#    length  popularity  danceability  acousticness  danceability  energy  \
# 0  184905          86         0.758        0.1600         0.758   0.598
# 1  199053          79         0.746        0.0112         0.746   0.765
# 2  187541          98         0.935        0.0194         0.935   0.454
# 3  140525         100         0.700        0.2210         0.700   0.722
# 4  261492          95         0.761        0.2440         0.761   0.518
#
#    instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# 0          0.000000    0.2950    -5.695       0.0868  149.836               4
# 1          0.000000    0.0936    -4.410       0.0993  114.044               4
# 2          0.000000    0.0824    -7.509       0.3750  133.073               4
# 3          0.000000    0.2720    -3.558       0.0369   90.989               4
# 4          0.000035    0.1070    -8.871       0.1340  133.976               4

# %%
#album = sp.album("2Y9IRtehByVkegoD7TcLfi")
#print(album)
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'}, 'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5', 'id': '0L8ExT028jH3ddEcZwqJJ5', 'name': 'Red Hot Chili Peppers', 'type': 'artist', 'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'copyrights': [{'text': '2006 Warner Records Inc.', 'type': 'C'}, {'text': '2006 Warner Records Inc.', 'type': 'P'}], 'external_ids': {'upc': '093624424161'}, 'external_urls': {'spotify': 'https://open.spotify.com/album/2Y9IRtehByVkegoD7TcLfi'}, 'genres': [], 'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi', 'id': '2Y9IRtehByVkegoD7TcLfi', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27394d08ab63e57b0cae74e8595', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0294d08ab63e57b0cae74e8595', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485194d08ab63e57b0cae74e8595', 'width': 64}], 'label': 'Warner Records', 'name': 'Californication (Deluxe Edition)', 'popularity': 83, 'release_date': '1999-06-08', 'release_date_precision': 'day', 'total_tracks': 18, 'tracks': {'href': 'https://api.spotify.com/v1/albums/2Y9IRtehByVkegoD7TcLfi/tracks?offset=0&limit=50', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'}, 'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5', 'id': '0L8ExT028jH3ddEcZwqJJ5', 'name': 'Red Hot Chili Peppers', 'type': 'artist', 'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 238733, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/0aGQHMr7bc23Y9Ts84ffop'}, 'href': 'https://api.spotify.com/v1/tracks/0aGQHMr7bc23Y9Ts84ffop', 'id': '0aGQHMr7bc23Y9Ts84ffop', 'is_local': False, 'name': 'Around the World', 'preview_url': 'https://p.scdn.co/mp3-preview/ab3d501c5ffbf560e94094f76cd36d874a26e941?cid=b3c5b350c6cb43c2bdb403eb3b896eba', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:0aGQHMr7bc23Y9Ts84ffop'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'}, 'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5', 'id': '0L8ExT028jH3ddEcZwqJJ5', 'name': 'Red Hot Chili Peppers', 'type': 'artist', 'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RS', 'SA', 'SE', ' ...

# %%
# Out:
# {'collaborative': False, 'description': '', 'external_urls': {'spotify': 'https://open.spotify.com/playlist/6UnNMJ5CBpnZmybptaEAEz'}, 'followers': {'href': None, 'total': 20531}, 'href': 'https://api.spotify.com/v1/playlists/6UnNMJ5CBpnZmybptaEAEz?additional_types=track', 'id': '6UnNMJ5CBpnZmybptaEAEz', 'images': [{'height': 640, 'url': 'https://mosaic.scdn.co/640/ab67616d0000b2736ca5c90113b30c3c43ffb8f4ab67616d0000b273726d48d93d02e1271774f023ab67616d0000b2739bef45ee387f274ea3198c55ab67616d0000b273dbb3dd82da45b7d7f31b1b42', 'width': 640}, {'height': 300, 'url': 'https://mosaic.scdn.co/300/ab67616d0000b2736ca5c90113b30c3c43ffb8f4ab67616d0000b273726d48d93d02e1271774f023ab67616d0000b2739bef45ee387f274ea3198c55ab67616d0000b273dbb3dd82da45b7d7f31b1b42', 'width': 300}, {'height': 60, 'url': 'https://mosaic.scdn.co/60/ab67616d0000b2736ca5c90113b30c3c43ffb8f4ab67616d0000b273726d48d93d02e1271774f023ab67616d0000b2739bef45ee387f274ea3198c55ab67616d0000b273dbb3dd82da45b7d7f31b1b42', 'width': 60}], 'name': 'Eminem Old School', 'owner': {'display_name': 'Sander van der Wal', 'external_urls': {'spotify': 'https://open.spotify.com/user/swaggerific'}, 'href': 'https://api.spotify.com/v1/users/swaggerific', 'id': 'swaggerific', 'type': 'user', 'uri': 'spotify:user:swaggerific'}, 'primary_color': None, 'public': True, 'snapshot_id': 'NTcsZTZkMTM4MzdmZWYyNDU0OGNkNTkyMGJlMTExYmRhNGRlNjFjOTljYQ==', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/6UnNMJ5CBpnZmybptaEAEz/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '2014-03-12T21:50:46Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/swaggerific'}, 'href': 'https://api.spotify.com/v1/users/swaggerific', 'id': 'swaggerific', 'type': 'user', 'uri': 'spotify:user:swaggerific'}, 'is_local': False, 'primary_color': None, 'track': {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'available_markets': [], 'external_urls': {'spotify': 'https://open.spotify.com/album/0JnN0ZgNrYxz3Gk725HiAd'}, 'href': 'https://api.spotify.com/v1/albums/0JnN0ZgNrYxz3Gk725HiAd', 'id': '0JnN0ZgNrYxz3Gk725HiAd', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273453ae7a025c637725f9fc4a9', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02453ae7a025c637725f9fc4a9', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851453ae7a025c637725f9fc4a9', 'width': 64}], 'name': 'The Slim Shady LP (Explicit)', 'release_date': '1999-02-23', 'release_date_precision': 'day', 'total_tracks': 20, 'type': 'album', 'uri': 'spotify:album:0JnN0ZgNrYxz3Gk725HiAd'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'available_markets': [], 'disc_number': 1, 'duration_ms': 226733, 'episode': False, 'explicit': True, 'external_ids': {'isrc': 'USIR19902007'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/56wRzRP0qlws0Cc1fFSLl6'}, 'href': 'https://api.spotify.com/v1/tracks/56wRzRP0qlws0Cc1fFSLl6', 'id': '56wRzRP0qlws0Cc1fFSLl6', 'is_local': False, 'name': 'Brain Damage', 'popularity': 0, 'preview_url': None, 'track': True, 'track_number': 4, 'type': 'track', 'uri': 'spotify:track:56wRzRP0qlws0Cc1fFSLl6'}, 'video_thumbnail': {'url': None}}, {'added_at': '2014-03-12T21:51:08Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/swaggerific'}, 'href': 'https://api.spotify.com/v1/users/swaggerific', 'id': 'swaggerific', 'type': 'user', 'uri': 'spotify:user:swaggerific'}, 'is_local': Fals ...
